# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Query
# * The query function in pandas is a useful function that acts similar to the "where" clause in SQL.
# * It is helpful for people who are coming from SQL background, so instead of using loc, iloc
# they can use query() that provides similar look and feel to filter data

# %% [markdown]
# #### Syntax
# **dataframe.query(expression, inplace = False)**
#
# * `expression` is some sort of logical expression that describes which rows to return in the output.
# * If the expression is true for a particular row, the row will be included in the output.
# * If the expression is false for a particular row, that row will be excluded from the output.
# * The expression must be enclosed inside of quotations

# %%
emp = pd.read_csv(r'./data/employees.csv')

# %%
emp.shape
# Out:
# (1000, 8)

# %%
emp.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
emp.dtypes
# Out:
# First Name            object
# Gender                object
# Start Date            object
# Last Login Time       object
# Salary                 int64
# Bonus %              float64
# Senior Management     object
# Team                  object
# dtype: object

# %%
emp.isna().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
# replace space with underscore in column names

# query() has limitations on what columns you can query with it. 
# A rule of thumb is that, if the name isn't a valid python identifier name, then it just won't work.

emp.columns = emp.columns.str.replace(' ','_')

# %%
emp.head(3)
# Out:
#   First_Name  Gender Start_Date Last_Login_Time  Salary  Bonus_%  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior_Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %% [markdown]
# <b> Query: Select only those employees who are in Senior Management </b>

# %%
emp.query("Senior_Management == True").head()
# Out:
#   First_Name  Gender Start_Date Last_Login_Time  Salary  Bonus_%  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 6       Ruby  Female  8/17/1987         4:20 PM   65476   10.012
#
#   Senior_Management             Team
# 0              True        Marketing
# 1              True              NaN
# 3              True          Finance
# 4              True  Client Services
# 6              True          Product

# %% [markdown]
# <b>Query: Select Senior Management of Marketing Team</b>

# %%
emp.query("Senior_Management == True and Team == 'Marketing'").head()
# Out:
#    First_Name  Gender Start_Date Last_Login_Time  Salary  Bonus_%  \
# 0     Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 26      Craig    Male  2/27/2000         7:45 AM   37598    7.757
# 43    Marilyn  Female  12/7/1980         3:16 AM   73524    5.207
# 77    Charles    Male  9/14/2004         8:13 PM  107391    1.260
# 97      Laura     NaN  7/19/2014         9:23 PM  140371   10.620
#
#    Senior_Management       Team
# 0               True  Marketing
# 26              True  Marketing
# 43              True  Marketing
# 77              True  Marketing
# 97              True  Marketing

# %% [markdown]
# <b>Query: We can also search using objects which are in memory, by using name of object preceded by @</b>

# %%
Team_List = ['Marketing', 'Sales', 'Finance']

emp.query("Team in @Team_List and Senior_Management == True").head()
# Out:
#    First_Name  Gender Start_Date Last_Login_Time  Salary  Bonus_%  \
# 0     Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 3       Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 14   Kimberly  Female  1/14/1999         7:13 AM   41426   14.543
# 26      Craig    Male  2/27/2000         7:45 AM   37598    7.757
# 43    Marilyn  Female  12/7/1980         3:16 AM   73524    5.207
#
#    Senior_Management       Team
# 0               True  Marketing
# 3               True    Finance
# 14              True    Finance
# 26              True  Marketing
# 43              True  Marketing

# %% [markdown]
# <b>Query: Find employee who got max bonus </b>

# %%
max_bonus = np.max(emp['Bonus_%'])

# %%
emp.query("`Bonus_%` == @max_bonus")
# Out:
#     First_Name Gender Start_Date Last_Login_Time  Salary  Bonus_%  \
# 488     Robert   Male  3/11/2007        11:20 AM  135882   19.944
#
#     Senior_Management   Team
# 488             False  Legal

# %% [markdown]
# <b>Query: Find all employees who were hired in same year when older employee was hired</b>

# %%
oldest_year = pd.to_datetime(emp.Start_Date).dt.year.min()
print(oldest_year)
# Out:
# 1980

# %%
emp.query("Start_Date.str.contains('1980')").head()
# Out:
#    First_Name  Gender Start_Date Last_Login_Time  Salary  Bonus_%  \
# 10     Louise  Female  8/12/1980         9:01 AM   63241   15.132
# 12    Brandon    Male  12/1/1980         1:08 AM  112807   17.492
# 43    Marilyn  Female  12/7/1980         3:16 AM   73524    5.207
# 45      Roger    Male  4/17/1980        11:32 AM   88010   13.886
# 49      Chris     NaN  1/24/1980        12:13 PM  113590    3.055
#
#    Senior_Management             Team
# 10              True              NaN
# 12              True  Human Resources
# 43              True        Marketing
# 45              True            Sales
# 49             False            Sales

# %% [markdown]
# <b>Query: Find all those records where Team value is missing </b>

# %%
emp.query('Team.isnull()').head()
# Out:
#    First_Name  Gender Start_Date Last_Login_Time  Salary  Bonus_%  \
# 1      Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 10     Louise  Female  8/12/1980         9:01 AM   63241   15.132
# 23        NaN    Male  6/14/2012         4:19 PM  125792    5.042
# 32        NaN    Male  8/21/1998         2:27 PM  122340    6.417
# 91      James     NaN  1/26/2005        11:00 PM  128771    8.309
#
#    Senior_Management Team
# 1               True  NaN
# 10              True  NaN
# 23               NaN  NaN
# 32               NaN  NaN
# 91             False  NaN

# %% [markdown]
# <b>Query: Both Team and Senior_Management info is missing </b>

# %%
emp.query("Team.isna() and Senior_Management.isna()").head()
# Out:
#     First_Name  Gender Start_Date Last_Login_Time  Salary  Bonus_%  \
# 23         NaN    Male  6/14/2012         4:19 PM  125792    5.042
# 32         NaN    Male  8/21/1998         2:27 PM  122340    6.417
# 139        NaN  Female  10/3/1990         1:08 AM  132373   10.527
# 382        NaN  Female  4/18/1996         3:57 PM  107024   12.182
# 567        NaN  Female   4/1/1980         8:04 PM   48141   12.605
#
#     Senior_Management Team
# 23                NaN  NaN
# 32                NaN  NaN
# 139               NaN  NaN
# 382               NaN  NaN
# 567               NaN  NaN

# %% [markdown]
# <b>Query all records who were hired in a specific year say 2010</b>

# %%
# convert Start_Date to datetime
emp['Start_Date'] = pd.to_datetime(emp['Start_Date'])

# %%
# sort the dataframe in ascending order of Start_Date
emp.sort_values('Start_Date', inplace = True)

# %%
# Set Start_Date as index
emp.set_index('Start_Date', inplace  = True)

# %%
emp.head()
# Out:
#            First_Name  Gender Last_Login_Time  Salary  Bonus_%  \
# Start_Date
# 1980-01-19        Joe    Male         4:06 PM  119667    1.148
# 1980-01-24      Chris     NaN        12:13 PM  113590    3.055
# 1980-01-28       Ruby  Female        11:08 PM  142868    6.318
# 1980-02-20       Fred    Male         2:25 AM   74129   18.225
# 1980-02-25       Sara  Female        10:50 PM   75484    3.186
#
#            Senior_Management       Team
# Start_Date
# 1980-01-19              True    Finance
# 1980-01-24             False      Sales
# 1980-01-28             False  Marketing
# 1980-02-20             False    Product
# 1980-02-25             False    Finance

# %%
emp.query("index.dt.year == 2010").head()
# Out:
#            First_Name  Gender Last_Login_Time  Salary  Bonus_%  \
# Start_Date
# 2010-01-19      Debra  Female         8:48 AM   70492    8.895
# 2010-01-27        NaN    Male         2:57 AM   87760   14.987
# 2010-02-04      Linda  Female         8:49 PM   44486   17.308
# 2010-02-16       Todd    Male        11:29 AM  103405   15.910
# 2010-02-21  Elizabeth  Female         7:02 AM   79145   19.780
#
#            Senior_Management             Team
# Start_Date
# 2010-01-19             False  Client Services
# 2010-01-27               NaN      Engineering
# 2010-02-04              True      Engineering
# 2010-02-16             False            Sales
# 2010-02-21             False          Finance

# %% [markdown]
# <b>Find employees who have completed 35 years of service</b>

# %%
from datetime import date

# %%
current_year = date.today().year

# %%
emp.query("(@current_year - index.dt.year) > 35").head()
# Out:
#            First_Name  Gender Last_Login_Time  Salary  Bonus_%  \
# Start_Date
# 1980-01-19        Joe    Male         4:06 PM  119667    1.148
# 1980-01-24      Chris     NaN        12:13 PM  113590    3.055
# 1980-01-28       Ruby  Female        11:08 PM  142868    6.318
# 1980-02-20       Fred    Male         2:25 AM   74129   18.225
# 1980-02-25       Sara  Female        10:50 PM   75484    3.186
#
#            Senior_Management       Team
# Start_Date
# 1980-01-19              True    Finance
# 1980-01-24             False      Sales
# 1980-01-28             False  Marketing
# 1980-02-20             False    Product
# 1980-02-25             False    Finance

# %% [markdown]
# <b>Chain Queries </b>

# %%
emp.query('Team == "Sales"').query("Gender == 'Female'").query("Senior_Management == True").head()
# Out:
#            First_Name  Gender Last_Login_Time  Salary  Bonus_%  \
# Start_Date
# 1982-07-05      Diane  Female         4:56 PM  124889   15.026
# 1983-06-04      Robin  Female         3:15 PM  114797    5.965
# 1984-01-02     Janice  Female         9:06 PM   41190    3.311
# 1987-05-08      Kathy  Female         6:19 PM   86318   18.492
# 1989-08-15    Marilyn  Female         9:14 AM  140502    9.989
#
#            Senior_Management   Team
# Start_Date
# 1982-07-05              True  Sales
# 1983-06-04              True  Sales
# 1984-01-02              True  Sales
# 1987-05-08              True  Sales
# 1989-08-15              True  Sales

# %%
emp.query('Team == "Sales"')['Salary'].mean()
# Out:
# 92173.43617021276
